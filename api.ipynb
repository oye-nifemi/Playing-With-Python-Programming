# %%
from randomuser import RandomUser
import pandas as pd

# %%
r = RandomUser()

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x23d1949a1a0>,
#  <randomuser.RandomUser at 0x23d19499f30>,
#  <randomuser.RandomUser at 0x23d19499f90>,
#  <randomuser.RandomUser at 0x23d19499f60>,
#  <randomuser.RandomUser at 0x23d1949a110>,
#  <randomuser.RandomUser at 0x23d19499fc0>,
#  <randomuser.RandomUser at 0x23d1949a140>,
#  <randomuser.RandomUser at 0x23d19499f00>,
#  <randomuser.RandomUser at 0x23d1949a050>,
#  <randomuser.RandomUser at 0x23d1949a230>]

# %%
name = r.get_full_name()

# %%
name
# Out:
# 'Imar Van der Ven'

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Veronica Schwaiger   veronica.schwaiger@example.com
# Rodi Van den Houten   rodi.vandenhouten@example.com
# آوین سلطانی نژاد   awyn.sltnynjd@example.com
# Sander Sørensen   sander.sorensen@example.com
# Murat Akman   murat.akman@example.com
# Bernard Meunier   bernard.meunier@example.com
# Ruben Santiago   ruben.santiago@example.com
# Louanne Olivier   louanne.olivier@example.com
# Beatrice Leroux   beatrice.leroux@example.com
# Inara Viana   inara.viana@example.com

# %%
# Generatte picture of random users
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/women/37.jpg
# https://randomuser.me/api/portraits/men/33.jpg
# https://randomuser.me/api/portraits/women/42.jpg
# https://randomuser.me/api/portraits/men/88.jpg
# https://randomuser.me/api/portraits/men/13.jpg
# https://randomuser.me/api/portraits/men/25.jpg
# https://randomuser.me/api/portraits/men/27.jpg
# https://randomuser.me/api/portraits/women/12.jpg
# https://randomuser.me/api/portraits/women/3.jpg
# https://randomuser.me/api/portraits/women/36.jpg

# %%
 #To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.
 
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
      
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#                Name  Gender         City           State  \
# 0    Adele Gonzalez  female      Ekeberg        Telemark
# 1  Stephen Fletcher    male    Liverpool  West Glamorgan
# 2      Amanda Maunu  female     Karkkila   North Karelia
# 3        Leevi Toro    male     Ristiina   South Karelia
# 4      Helena Dietz  female    Nederland    Zuid-Holland
# 5     Soledad Duran  female     Zaragoza       Andalucía
# 6       Oscar Hicks    male    Celbridge       Tipperary
# 7   Paula Robertson  female   Chesapeake         Vermont
# 8     Jennifer Lowe  female        Gorey           Laois
# 9    Thomas Vincent    male  Montpellier      Val-D'Oise
#
#                           Email                       DOB  \
# 0    adele.gonzalez@example.com  1998-03-06T01:30:27.477Z
# 1  stephen.fletcher@example.com  1989-07-04T11:52:32.361Z
# 2      amanda.maunu@example.com  1959-09-27T16:33:39.517Z
# 3        leevi.toro@example.com  1979-02-28T13:04:50.446Z
# 4      helena.dietz@example.com  1945-10-18T10:31:28.032Z
# 5     soledad.duran@example.com  1965-08-10T06:25:38.993Z
# 6       oscar.hicks@example.com  1979-01-02T07:04:33.408Z
# 7   paula.robertson@example.com  1962-06-22T13:57:10.001Z
# 8     jennifer.lowe@example.com  1946-01-06T14:33:07.106Z
# 9    thomas.vincent@example.com  1994-06-23T18:47:25.104Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/96.jpg
# 1    https://randomuser.me/api/portraits/men/70.jpg
# 2  https://randomuser.me/api/portraits/women/70.jpg
# 3    https://randomuser.me/api/portraits/men/37.jpg
# 4  https://randomuser.me/api/portraits/women/96.jpg
# 5  https://randomuser.me/api/portraits/women/96.jpg
# 6    https://randomuser.me/api/portraits/men/15.jpg
# 7  https://randomuser.me/api/portraits/women/19.jpg
# 8  https://randomuser.me/api/portraits/women/23.jpg
# 9    https://randomuser.me/api/portraits/men/59.jpg

# %%
df1 = pd.DataFrame(get_users())

# %%
df1
# Out:
#                    Name  Gender         City              State  \
# 0     Svetlana Großmann  female      Wegberg      Niedersachsen
# 1       Jeffrey Steward    male       Orange  Western Australia
# 2          Aurora Green  female        Taupo            Waikato
# 3          Harold Young    male    Arlington         New Jersey
# 4      Birgit Blanchard  female      Savièse             Valais
# 5          Rachel David  female        Nîmes           Calvados
# 6     Christopher Meyer    male  Londonderry       Warwickshire
# 7           Yolande Roy  female       Apples          Nidwalden
# 8  Sarita Van den Dries  female        Buren            Utrecht
# 9        Cécile Le Gall  female    Leibstadt               Jura
#
#                             Email                       DOB  \
# 0  svetlana.grossmann@example.com  1977-07-15T06:45:24.265Z
# 1     jeffrey.steward@example.com  1983-10-25T19:14:30.374Z
# 2        aurora.green@example.com  1971-11-13T13:50:14.371Z
# 3        harold.young@example.com  1955-05-23T14:39:25.412Z
# 4    birgit.blanchard@example.com  1964-05-07T04:23:56.895Z
# 5        rachel.david@example.com  1985-06-08T19:45:18.259Z
# 6   christopher.meyer@example.com  1991-03-07T03:13:36.417Z
# 7         yolande.roy@example.com  1971-06-28T07:53:36.656Z
# 8  sarita.vandendries@example.com  1956-05-21T06:23:34.640Z
# 9       cecile.legall@example.com  1979-03-28T17:33:06.461Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/88.jpg
# 1     https://randomuser.me/api/portraits/men/1.jpg
# 2  https://randomuser.me/api/portraits/women/24.jpg
# 3    https://randomuser.me/api/portraits/men/62.jpg
# 4  https://randomuser.me/api/portraits/women/56.jpg
# 5  https://randomuser.me/api/portraits/women/17.jpg
# 6    https://randomuser.me/api/portraits/men/98.jpg
# 7  https://randomuser.me/api/portraits/women/93.jpg
# 8  https://randomuser.me/api/portraits/women/72.jpg
# 9  https://randomuser.me/api/portraits/women/28.jpg

# %%
# Fruitvice API

import requests
import json

# %%
data = requests.get("https://www.fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 8   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 9   {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 10  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 11  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 12  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 29  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 30  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 31  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 32  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 33  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 34  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 35  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 36  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 37  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 38  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %%
df2 = pd.json_normalize(results)
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae              None
# 7   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 8          Durio        Durian  60        Malvaceae          Malvales
# 9     Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 10         Ficus           Fig  68         Moraceae           Rosales
# 11         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 12         Vitis         Grape  81         Vitaceae           Vitales
# 13         Vitis        Grapes  47         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28         Pyrus          Pear   4         Rosaceae           Rosales
# 29     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 30        Ananas     Pineapple  10     Bromeliaceae            Poales
# 31     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 32        Prunus          Plum  71         Rosaceae           Rosales
# 33        Punica   Pomegranate  79       Lythraceae          Myrtales
# 34         Rubus     Raspberry  23         Rosaceae           Rosales
# 35      Fragaria    Strawberry   3         Rosaceae           Rosales
# 36        Citrus     Tangerine  77         Rutaceae        Sapindales
# 37       Solanum        Tomato   5       Solanaceae         Solanales
# 38     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                       9.00                9.00            1.50
# 8                      27.10                1.50            5.30
# 9                       8.00                0.60            0.40
# 10                     19.00                0.80            0.30
# 11                     10.00                0.90            0.60
# 12                     18.10                0.72            0.16
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                     15.00                0.40            0.10
# 29                     18.00                0.00            0.00
# 30                     13.12                0.54            0.12
# 31                      7.00                1.00            0.40
# 32                     11.40                0.70            0.28
# 33                     18.70                1.70            1.20
# 34                     12.00                1.20            0.70
# 35                      5.50                0.80            0.40
# 36                      8.30                0.00            0.40
# 37                      3.90                0.90            0.20
# 38                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    60              8.00
# 8                   147              6.75
# 9                    44              3.00
# 10                   74             16.00
# 11                   44              0.00
# 12                   69             16.00
# 13                   69             15.48
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   57             10.00
# 29                   81             18.00
# 30                   50              9.85
# 31                   36              3.00
# 32                   46              9.92
# 33                   83             13.70
# 34                   53              4.40
# 35                   29              5.40
# 36                   45              9.10
# 37                   74              2.60
# 38                   30              6.00

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')
